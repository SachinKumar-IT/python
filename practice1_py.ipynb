# %% [markdown]
# <a href="https://colab.research.google.com/github/SachinKumar-IT/python/blob/main/practice1_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = 75
if num <= 50:
  pass
elif num <=75:
  print("1")
elif num <=80:
  print("2")
# Out:
# 1

# %%
a=int(input("enter 1st number:"))
b=int(input("enter 2nd number:"))
temp=a
a=b
b=temp
print("a=",a)
print("b=",b)
# Out:
# enter 1st number:1
# enter 2nd number:2
# a= 2
# b= 1
